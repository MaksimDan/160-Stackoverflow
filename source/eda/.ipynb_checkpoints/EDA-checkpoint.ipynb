# %%
# %matplotlib inline

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (15, 10)
import numpy as np
import seaborn as sns

# %% [markdown]
# # EDA
# ## Load Data

# %%
Badges = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Badges.csv')
Comments = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Comments.csv')
PostHistory = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/PostHistory.csv')
Postlinks = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Postlinks.csv')
Posts = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Posts.csv')
Users = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Users.csv')
Votes = pd.read_csv('/Users/esmondchu/Dropbox/160-Stackoverflow-Data/100000_rows_[168_MB]/Votes.csv')

# %% [markdown]
# ## Check NA of Posts

# %%
sns.heatmap(Posts.isnull(), yticklabels=False, cbar=False)
plt.title('Posts NA')
# Out:
# Text(0.5,1,'Posts NA')

# %%
Posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
# Id                       100000 non-null int64
# PostTypeId               100000 non-null int64
# ParentID                 81053 non-null float64
# AcceptedAnswerId         15069 non-null float64
# CreationDate             100000 non-null object
# Score                    100000 non-null int64
# ViewCount                18947 non-null float64
# Body                     100000 non-null object
# OwnerUserId              96210 non-null float64
# LastEditorUserId         35095 non-null float64
# LastEditorDisplayName    21143 non-null object
# LastEditDate             35478 non-null object
# LastActivityDate         100000 non-null object
# CommunityOwnedDate       5502 non-null object
# ClosedDate               2047 non-null object
# Title                    18947 non-null object
# Tags                     18947 non-null object
# AnswerCount              18947 non-null float64
# CommentCount             100000 non-null int64
# FavoriteCount            12767 non-null float64
# dtypes: float64(7), int64(4), object(9)
# memory usage: 15.3+ MB

# %% [markdown]
# # Timely Collaboration and Values
# ## Answers Posts

# %%
import datetime
import calendar

#date to timestamp
def date_ts(s):
    """ 
    param s: str - date
    returns: int - timestamp
    """
    date = datetime.datetime.strptime(s, "%Y-%m-%dT%H:%M:%S")
    st = calendar.timegm(date.utctimetuple())
    return(st)

# %%
df_answers = Posts[Posts.PostTypeId == 2]

# %%
df_answers = df_answers.reset_index(drop=True)

# %%
df_answers.CreationDate = df_answers.CreationDate.str[:-4]

# %%
unix_ans = [date_ts(i) for i in df_answers.CreationDate]

# %%
df_answers_time = pd.DataFrame({'ParentID':df_answers.ParentID, 'Cr_time':unix_ans})

# %%
df_list = df_answers_time.groupby(df_answers_time.ParentID)

# %%
uni_par_id = list(df_answers_time.ParentID.unique())

# %%
ans_date = [list(df_list.get_group(i).Cr_time) for i in uni_par_id]

# %%
yes = 0
no = 0
for i in ans_date:
    if len(i) == 1:
        yes += 1
    else:
        no += 1
print(yes, no)

#there are 2917 posts with only 1 answer, 15773 posts with more than 1 answers.
# Out:
# 2917 15773

# %%
#set 1-answer post sd to 0
for i in ans_date:
    if len(i) == 1:
        i.append(i[0])
    else:
        i == i

# %%
import statistics
ans_time_sd = [statistics.stdev(i) for i in ans_date]

# %%
post_Id = sorted(list(df_answers.ParentID.unique()))

# %%
post_ans_sd = pd.DataFrame({'post_Id':post_Id, 'time_sd':ans_time_sd})

# %%
post_ans_sd.head()
# Out:
#    post_Id       time_sd
# 0      4.0  1.724331e+06
# 1      6.0  1.628865e+06
# 2      9.0  2.005625e+06
# 3     11.0  1.567259e+06
# 4     13.0  9.701637e+05

# %% [markdown]
# ## Parents Posts

# %%
Parents_post = Posts[Posts.PostTypeId == 1]

# %%
Parents_post = Parents_post.reset_index(drop=True)

# %%
Parents_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18947 entries, 0 to 18946
# Data columns (total 20 columns):
# Id                       18947 non-null int64
# PostTypeId               18947 non-null int64
# ParentID                 0 non-null float64
# AcceptedAnswerId         15069 non-null float64
# CreationDate             18947 non-null object
# Score                    18947 non-null int64
# ViewCount                18947 non-null float64
# Body                     18947 non-null object
# OwnerUserId              17701 non-null float64
# LastEditorUserId         14223 non-null float64
# LastEditorDisplayName    9820 non-null object
# LastEditDate             14381 non-null object
# LastActivityDate         18947 non-null object
# CommunityOwnedDate       715 non-null object
# ClosedDate               2047 non-null object
# Title                    18947 non-null object
# Tags                     18947 non-null object
# AnswerCount              18947 non-null float64
# CommentCount             18947 non-null int64
# FavoriteCount            12767 non-null float64
# dtypes: float64(7), int64(4), object(9)
# memory usage: 2.9+ MB

# %%
df_parents = pd.DataFrame({'post_Id':Parents_post.Id, 'Views_count':Parents_post.ViewCount,\
                           'Score':Parents_post.Score, 'Comment_count':Parents_post.CommentCount})

# %%
df_comb = df_parents.join(post_ans_sd.set_index('post_Id'), on='post_Id')

# %%
df_comb.head()
# Out:
#    Comment_count  Score  Views_count post_Id       time_sd
# 0              1    543      34799.0       4  1.724331e+06
# 1              0    241      15696.0       6  1.628865e+06
# 2             16   1716     439828.0       9  2.005625e+06
# 3              3   1286     130055.0      11  1.567259e+06
# 4              6    519     149911.0      13  9.701637e+05

# %% [markdown]
# ## Plots

# %%
f, (ax1, ax2) = plt.subplots(nrows=2, figsize=(8,10))
plt.suptitle("Question Value vs Timely Collaboration", size=20)
sns.regplot(df_comb.time_sd, df_comb.Score, marker=".", ax=ax1)
sns.regplot(df_comb.time_sd, df_comb.Views_count, marker=".", ax=ax2)

# %% [markdown]
# ## Data transformation

# %%
df_comb.head()
# Out:
#    Comment_count  Score  Views_count post_Id       time_sd
# 0              1    543      34799.0       4  1.724331e+06
# 1              0    241      15696.0       6  1.628865e+06
# 2             16   1716     439828.0       9  2.005625e+06
# 3              3   1286     130055.0      11  1.567259e+06
# 4              6    519     149911.0      13  9.701637e+05

# %%
df_comb.Views_count.describe()
# Out:
# count    1.894700e+04
# mean     3.093298e+04
# std      1.129652e+05
# min      5.900000e+01
# 25%      1.401500e+03
# 50%      4.288000e+03
# 75%      1.628700e+04
# max      3.328490e+06
# Name: Views_count, dtype: float64

# %%
df_comb.Score.describe()
# Out:
# count    18947.000000
# mean        42.317306
# std        201.475094
# min         -7.000000
# 25%          2.000000
# 50%          6.000000
# 75%         19.000000
# max       7658.000000
# Name: Score, dtype: float64

# %%
import math
def loga(x):
    val = x+9
    out = 1/math.log10(val)
    return(out)

# %%
View_log = df_comb.Views_count.apply(loga)

# %%
Scores_log = df_comb.Score.apply(loga)

# %%
yes = 0
no = 0
for i in df_comb.Score:
    if i < 0:
        yes += 1
    else:
        no += 1
print(yes, no)
# Out:
# 102 18845

# %% [markdown]
# ## Plot of Transformed Data

# %%
f, (ax1, ax2) = plt.subplots(nrows=2, figsize=(8,10))
plt.suptitle("Question Value vs Timely Collaboration", size=20)
sns.regplot(df_comb.time_sd, View_log, ax=ax1)
sns.regplot(df_comb.time_sd, Scores_log, ax=ax2)

# %% [markdown]
# # Probability of a question being answered as a function of time in minutes
# eg. $P(\text{question is answered}|t=0,...,n , n=1,...,1440)$ for

# %% [markdown]
# ## Parents Post Data Wrangling

# %%
#Parents_post
df_answers
# Out:
#            Id  PostTypeId  ParentID  AcceptedAnswerId         CreationDate  \
# 0           7           2       4.0               NaN  2008-07-31T22:17:57
# 1          12           2      11.0               NaN  2008-07-31T23:56:41
# 2          18           2      17.0               NaN  2008-08-01T05:12:44
# 3          21           2       9.0               NaN  2008-08-01T08:57:27
# 4          22           2       9.0               NaN  2008-08-01T12:07:19
# 5          26           2      17.0               NaN  2008-08-01T12:16:22
# 6          27           2      11.0               NaN  2008-08-01T12:17:19
# 7          29           2      13.0               NaN  2008-08-01T12:19:17
# 8          30           2      25.0               NaN  2008-08-01T12:22:40
# 9          31           2       6.0               NaN  2008-08-01T12:22:51
# 10         33           2      14.0               NaN  2008-08-01T12:26:39
# 11         44           2      39.0               NaN  2008-08-01T12:55:42
# 12         45           2      39.0               NaN  2008-08-01T12:56:37
# 13         49           2      24.0               NaN  2008-08-01T13:02:51
# 14         51           2      36.0               NaN  2008-08-01T13:07:52
# 15         52           2      34.0               NaN  2008-08-01T13:08:59
# 16         53           2      34.0               NaN  2008-08-01T13:08:59
# 17         56           2      48.0               NaN  2008-08-01T13:10:16
# 18         58           2      48.0               NaN  2008-08-01T13:14:30
# 19         60           2      34.0               NaN  2008-08-01T13:14:40
# 20         62           2      59.0               NaN  2008-08-01T13:18:37
# 21         65           2      61.0               NaN  2008-08-01T13:20:44
# 22         68           2      66.0               NaN  2008-08-01T13:22:04
# 23         71           2      19.0               NaN  2008-08-01T13:37:59
# 24         73           2      25.0               NaN  2008-08-01T13:40:16
# 25         76           2      42.0               NaN  2008-08-01T13:44:35
# 26         77           2      42.0               NaN  2008-08-01T13:46:00
# 27         78           2       4.0               NaN  2008-08-01T13:53:06
# 28         81           2      34.0               NaN  2008-08-01T14:03:22
# 29         82           2      36.0               NaN  2008-08-01T14:06:28
# ...       ...         ...       ...               ...                  ...
# 81023  159838           2  142830.0               NaN  2008-10-01T21:27:25
# 81024  159840           2   69546.0               NaN  2008-10-01T21:27:32
# 81025  159841           2  159039.0               NaN  2008-10-01T21:27:50
# 81026  159843           2  159625.0               NaN  2008-10-01T21:28:11
# 81027  159844           2  135664.0               NaN  2008-10-01T21:28:21
# 81028  159845           2   20034.0               NaN  2008-10-01T21:28:26
# 81029  159847           2  159768.0               NaN  2008-10-01T21:29:16
# 81030  159848           2  157770.0               NaN  2008-10-01T21:29:22
# 81031  159850           2  159597.0               NaN  2008-10-01T21:29:36
# 81032  159851           2  136752.0               NaN  2008-10-01T21:29:42
# 81033  159854           2  159821.0               NaN  2008-10-01T21:30:07
# 81034  159857           2  159797.0               NaN  2008-10-01T21:30:40
# 81035  159858           2  159846.0               NaN  2008-10-01T21:31:13
# 81036  159859           2  148729.0               NaN  2008-10-01T21:31:51
# 81037  159860           2  159837.0               NaN  2008-10-01T21:32:15
# 81038  159861           2  159837.0               NaN  2008-10-01T21:32:16
# 81039  159863           2  159732.0               NaN  2008-10-01T21:32:43
# 81040  159865           2  159842.0               NaN  2008-10-01T21:33:02
# 81041  159866           2  159853.0               NaN  2008-10-01T21:33:44
# 81042  159867           2  159862.0               NaN  2008-10-01T21:33:45
# 81043  159868           2  159705.0               NaN  2008-10-01T21:33:46
# 81044  159871           2  159842.0               NaN  2008-10-01T21:34:33
# 81045  159872           2  159862.0               NaN  2008-10-01T21:34:51
# 81046  159873           2  159597.0               NaN  2008-10-01T21:34:55
# 81047  159874           2  105659.0               NaN  2008-10-01T21:35:37
# 81048  159876           2  155366.0               NaN  2008-10-01T21:36:17
# 81049  159878           2  159862.0               NaN  2008-10-01T21:36:56
# 81050  159879           2  144250.0               NaN  2008-10-01T21:37:36
# 81051  159880           2  154686.0               NaN  2008-10-01T21:38:25
# 81052  159882           2  159862.0               NaN  2008-10-01T21:41:07
#
#        Score  ViewCount                                               Body  \
# 0        391        NaN  <p>An explicit cast to double like this isn't ...
# 1        313        NaN  <p>Here's how I do it</p>\r\n\r\n<pre class="l...
# 2         50        NaN  <p>For a table like this:</p>\r\n\r\n<pre><cod...
# 3         31        NaN  <p>Many years ago, to provide an <a href="http...
# 4         24        NaN  <p>The best way that I know of because of leap...
# 5        122        NaN  <p>The answer by phpguy is correct but I think...
# 6         28        NaN  <p>@jeff</p>\r\n\r\n<p>IMHO yours seems a litt...
# 7         73        NaN  <p>There are no HTTP headers that will report ...
# 8         32        NaN  <p>I've had no trouble using the BSD sockets A...
# 9        127        NaN  <p>The parent <code>div</code> needs to have a...
# 10       419        NaN  <p><code>Math.Floor</code> rounds down, <code>...
# 11        15        NaN  <p>Consider using a <a href="http://msdn.micro...
# 12        48        NaN  <p>You can use something like <code>Console.Re...
# 13        50        NaN  <p><a href="http://www.brokenbuild.com/blog/20...
# 14        24        NaN  <p>Why don't you want to use triggers?  They a...
# 15        15        NaN  <p>Have a look at this article</p>\r\n\r\n<p><...
# 16        19        NaN  <p>(I'm not positive about this, but...)</p>\r...
# 17        53        NaN  <p>Give your submit buttons same name like thi...
# 18        60        NaN  <p>Would it be possible for you to change the ...
# 19        13        NaN  <p>Unfortunately when it comes to memory manag...
# 20        50        NaN  <p><strong>The problem is that the Distinct\r\...
# 21        22        NaN  <p><a href="http://www.bram.us/2007/05/25/offi...
# 22        59        NaN  <p>It is very simple with the <code>Skip</code...
# 23        68        NaN  <p>Here's a general description of a technique...
# 24        15        NaN  <p>@Jax: The <code>extern "C"</code> thing mat...
# 25        13        NaN  <p>I believe the easiest way would be to follo...
# 26       149        NaN  <p>You could use an Observer pattern.  A simpl...
# 27        53        NaN  <p>It sounds like <code>this.Opacity</code> is...
# 28        13        NaN  <p>I believe you have answered your own questi...
# 29        18        NaN  <p>Have a DTS job (or a job that is started by...
# ...      ...        ...                                                ...
# 81023      0        NaN  <p>A really important thing to check for when ...
# 81024      1        NaN  <p>Instead of having the JS code out in the op...
# 81025      4        NaN  <p><a href="http://haxe.org/" rel="nofollow no...
# 81026      1        NaN  <p>Do what your users need. For instance, most...
# 81027      3        NaN  <blockquote>\r\n  <p>A new function, <code>get...
# 81028      1        NaN  <p>It sounds like fun to design and code, but ...
# 81029      0        NaN  <p>Georgi:</p>\r\n\r\n<p>That would help if it...
# 81030     35        NaN  <p>As far as I know, you can only format the f...
# 81031      0        NaN  <p>Only employ good engineers who ensure their...
# 81032      1        NaN  <p>FWIW, I've switched to using <code>CaptureS...
# 81033     -1        NaN  <p>I think a blank row is probably the only wa...
# 81034     30        NaN  <p>I most definitely think you can use functio...
# 81035      0        NaN  <p>Usually, when linking to other libraries, y...
# 81036      1        NaN  <p>The second border which gets added is the W...
# 81037      0        NaN  <p>Difficult to do depending on the permission...
# 81038      3        NaN  <p>PSloggedon from SysInternals will provide t...
# 81039      3        NaN  <p>@1800 INFORMATION</p>\r\n\r\n<p>Maybe we co...
# 81040      2        NaN  <p>No, you'll need to refactor your JavaScript...
# 81041      0        NaN  <p>If you're building a patch, you might want ...
# 81042      1        NaN  <p>You may find or be able to make a macro to ...
# 81043      1        NaN  <p>First, they're not equivalent. The 1st samp...
# 81044     10        NaN  <p>If you want to evaluate <code>&lt;% code bl...
# 81045      1        NaN  <p>ReSharper has <a href="http://www.jetbrains...
# 81046      0        NaN  <p>I am also in the camp of less comments the ...
# 81047      4        NaN  <p>For Windows, <code>CaptureStackBackTrace()<...
# 81048      0        NaN  <p>Have you tried just a simple Control.GotFoc...
# 81049      0        NaN  <p>Resharper will do a good job in a limited w...
# 81050      1        NaN  <p>To do something similar in my application, ...
# 81051      2        NaN  <p>You could probably use the ${extract} opera...
# 81052     10        NaN  <p>This is a free plug-in that does what you a...
#
#        OwnerUserId  LastEditorUserId LastEditorDisplayName  \
# 0              9.0         4020527.0                   NaN
# 1              1.0         1271898.0            GateKiller
# 2              NaN          126039.0           Jeff Atwood
# 3             13.0              13.0    Chris Jester-Young
# 4             17.0              17.0                  Nick
# 5             48.0          126039.0          Geoff Dalgas
# 6             17.0              17.0          Nick Berardi
# 7             19.0               NaN                   NaN
# 8             13.0               NaN                   NaN
# 9              NaN           63550.0                   NaN
# 10            13.0              -1.0                   NaN
# 11            35.0          967315.0                   NaN
# 12            39.0          967315.0              huseyint
# 13            43.0          957909.0                   NaN
# 14            17.0         3735690.0                   NaN
# 15            23.0               NaN                   NaN
# 16            34.0         1668244.0                   NaN
# 17            39.0         2354564.0                   NaN
# 18            37.0          875317.0                   NaN
# 19            41.0         2354564.0                   NaN
# 20            45.0         1248536.0                   NaN
# 21            35.0         5898312.0                   NaN
# 22            17.0         1039608.0                   NaN
# 23            49.0           63550.0                   NaN
# 24            13.0              13.0    Chris Jester-Young
# 25            50.0               NaN                   NaN
# 26            40.0         4380409.0                   NaN
# 27            55.0          967315.0                   NaN
# 28            41.0          967315.0                   NaN
# 29            51.0               NaN                   NaN
# ...            ...               ...                   ...
# 81023      23072.0               NaN                   NaN
# 81024      23501.0               NaN                   NaN
# 81025       4540.0         2631715.0                   NaN
# 81026      23952.0               NaN                   NaN
# 81027      20310.0           20310.0            Constantin
# 81028       8435.0               NaN                   NaN
# 81029      24302.0               NaN                   NaN
# 81030      24190.0               NaN                   NaN
# 81031      23234.0               NaN                   NaN
# 81032      19505.0               NaN                   NaN
# 81033      17826.0               NaN                   NaN
# 81034        122.0               NaN                   NaN
# 81035      23234.0               NaN                   NaN
# 81036      14048.0               NaN                   NaN
# 81037       1358.0               NaN                   NaN
# 81038       4490.0               NaN                   NaN
# 81039       2820.0               NaN                   NaN
# 81040       2688.0               NaN                   NaN
# 81041       9940.0            9940.0            Mark Roddy
# 81042       5469.0               NaN                   NaN
# 81043       2199.0               NaN                   NaN
# 81044       1659.0            1659.0              marxidad
# 81045       2688.0            2688.0                bdukes
# 81046      14642.0               NaN                   NaN
# 81047      19505.0               NaN                   NaN
# 81048      23553.0               NaN                   NaN
# 81049      14642.0               NaN                   NaN
# 81050      17826.0               NaN                   NaN
# 81051      11815.0               NaN                   NaN
# 81052      13990.0         1838048.0                   NaN
#
#                   LastEditDate         LastActivityDate  \
# 0      2017-12-16T05:06:57.613  2017-12-16T05:06:57.613
# 1      2018-01-12T16:10:22.637  2018-01-12T16:10:22.637
# 2      2016-06-02T05:56:26.060  2016-06-02T05:56:26.060
# 3      2008-08-01T12:35:11.707  2008-08-01T12:35:11.707
# 4      2008-08-01T15:26:37.087  2008-08-01T15:26:37.087
# 5      2016-06-02T05:55:17.060  2016-06-02T05:55:17.060
# 6      2008-08-01T13:16:49.127  2008-08-01T13:16:49.127
# 7                          NaN  2008-08-01T12:19:17.417
# 8                          NaN  2008-08-01T12:22:40.797
# 9      2016-03-19T06:10:52.170  2016-03-19T06:10:52.170
# 10     2017-05-23T12:03:01.573  2009-10-14T02:09:03.030
# 11     2012-10-14T12:20:15.140  2012-10-14T12:20:15.140
# 12     2012-10-14T12:20:06.700  2012-10-14T12:20:06.700
# 13     2012-12-24T21:24:41.017  2012-12-24T21:24:41.017
# 14     2017-01-26T17:38:44.893  2017-01-26T17:38:44.893
# 15                         NaN  2008-08-01T13:08:59.127
# 16     2014-07-10T21:03:46.907  2014-07-10T21:03:46.907
# 17     2014-07-14T07:55:42.730  2014-07-14T07:55:42.730
# 18     2015-07-06T22:50:09.980  2015-07-06T22:50:09.980
# 19     2014-07-11T14:58:07.480  2014-07-11T14:58:07.480
# 20     2014-08-19T23:17:56.597  2014-08-19T23:17:56.597
# 21     2017-01-02T03:57:33.723  2017-01-02T03:57:33.723
# 22     2012-05-04T09:04:26.523  2012-05-04T09:04:26.523
# 23     2012-05-25T21:09:03.593  2012-05-25T21:09:03.593
# 24     2008-08-01T13:54:25.510  2008-08-01T13:54:25.510
# 25                         NaN  2008-08-01T13:44:35.843
# 26     2017-02-20T11:18:33.207  2017-02-20T11:18:33.207
# 27     2012-10-14T11:54:40.347  2012-10-14T11:54:40.347
# 28     2012-10-14T12:18:19.590  2012-10-14T12:18:19.590
# 29                         NaN  2008-08-01T14:06:28.560
# ...                        ...                      ...
# 81023                      NaN  2008-10-01T21:27:25.023
# 81024                      NaN  2008-10-01T21:27:32.307
# 81025  2017-12-15T21:11:16.750  2017-12-15T21:11:16.750
# 81026                      NaN  2008-10-01T21:28:11.667
# 81027  2008-10-01T21:43:17.170  2008-10-01T21:43:17.170
# 81028                      NaN  2008-10-01T21:28:26.050
# 81029                      NaN  2008-10-01T21:29:16.343
# 81030                      NaN  2008-10-01T21:29:22.210
# 81031                      NaN  2008-10-01T21:29:36.640
# 81032                      NaN  2008-10-01T21:29:42.817
# 81033                      NaN  2008-10-01T21:30:07.857
# 81034                      NaN  2008-10-01T21:30:40.927
# 81035                      NaN  2008-10-01T21:31:13.033
# 81036                      NaN  2008-10-01T21:31:51.033
# 81037                      NaN  2008-10-01T21:32:15.447
# 81038                      NaN  2008-10-01T21:32:16.617
# 81039                      NaN  2008-10-01T21:32:43.013
# 81040                      NaN  2008-10-01T21:33:02.140
# 81041  2008-10-01T21:58:42.827  2008-10-01T21:58:42.827
# 81042                      NaN  2008-10-01T21:33:45.367
# 81043                      NaN  2008-10-01T21:33:46.707
# 81044  2008-10-02T18:17:50.790  2008-10-02T18:17:50.790
# 81045  2008-10-01T21:45:02.563  2008-10-01T21:45:02.563
# 81046                      NaN  2008-10-01T21:34:55.677
# 81047                      NaN  2008-10-01T21:35:37.657
# 81048                      NaN  2008-10-01T21:36:17.747
# 81049                      NaN  2008-10-01T21:36:56.000
# 81050                      NaN  2008-10-01T21:37:36.997
# 81051                      NaN  2008-10-01T21:38:25.417
# 81052  2010-11-18T08:22:36.430  2010-11-18T08:22:36.430
#
#             CommunityOwnedDate ClosedDate Title Tags  AnswerCount  \
# 0                          NaN        NaN   NaN  NaN          NaN
# 1      2009-09-04T13:15:59.820        NaN   NaN  NaN          NaN
# 2                          NaN        NaN   NaN  NaN          NaN
# 3      2011-08-16T19:40:43.080        NaN   NaN  NaN          NaN
# 4      2011-08-16T19:40:43.080        NaN   NaN  NaN          NaN
# 5                          NaN        NaN   NaN  NaN          NaN
# 6      2009-09-04T13:15:59.820        NaN   NaN  NaN          NaN
# 7                          NaN        NaN   NaN  NaN          NaN
# 8                          NaN        NaN   NaN  NaN          NaN
# 9                          NaN        NaN   NaN  NaN          NaN
# 10                         NaN        NaN   NaN  NaN          NaN
# 11                         NaN        NaN   NaN  NaN          NaN
# 12                         NaN        NaN   NaN  NaN          NaN
# 13                         NaN        NaN   NaN  NaN          NaN
# 14                         NaN        NaN   NaN  NaN          NaN
# 15                         NaN        NaN   NaN  NaN          NaN
# 16                         NaN        NaN   NaN  NaN          NaN
# 17                         NaN        NaN   NaN  NaN          NaN
# 18                         NaN        NaN   NaN  NaN          NaN
# 19                         NaN        NaN   NaN  NaN          NaN
# 20                         NaN        NaN   NaN  NaN          NaN
# 21                         NaN        NaN   NaN  NaN          NaN
# 22                         NaN        NaN   NaN  NaN          NaN
# 23                         NaN        NaN   NaN  NaN          NaN
# 24                         NaN        NaN   NaN  NaN          NaN
# 25                         NaN        NaN   NaN  NaN          NaN
# 26     2011-02-10T01:43:58.203        NaN   NaN  NaN          NaN
# 27                         NaN        NaN   NaN  NaN          NaN
# 28                         NaN        NaN   NaN  NaN          NaN
# 29                         NaN        NaN   NaN  NaN          NaN
# ...                        ...        ...   ...  ...          ...
# 81023                      NaN        NaN   NaN  NaN          NaN
# 81024                      NaN        NaN   NaN  NaN          NaN
# 81025                      NaN        NaN   NaN  NaN          NaN
# 81026                      NaN        NaN   NaN  NaN          NaN
# 81027                      NaN        NaN   NaN  NaN          NaN
# 81028                      NaN        NaN   NaN  NaN          NaN
# 81029                      NaN        NaN   NaN  NaN          NaN
# 81030                      NaN        NaN   NaN  NaN          NaN
# 81031  2008-10-01T22:35:08.497        NaN   NaN  NaN          NaN
# 81032                      NaN        NaN   NaN  NaN          NaN
# 81033                      NaN        NaN   NaN  NaN          NaN
# 81034                      NaN        NaN   NaN  NaN          NaN
# 81035                      NaN        NaN   NaN  NaN          NaN
# 81036                      NaN        NaN   NaN  NaN          NaN
# 81037                      NaN        NaN   NaN  NaN          NaN
# 81038                      NaN        NaN   NaN  NaN          NaN
# 81039                      NaN        NaN   NaN  NaN          NaN
# 81040                      NaN        NaN   NaN  NaN          NaN
# 81041                      NaN        NaN   NaN  NaN          NaN
# 81042                      NaN        NaN   NaN  NaN          NaN
# 81043                      NaN        NaN   NaN  NaN          NaN
# 81044                      NaN        NaN   NaN  NaN          NaN
# 81045                      NaN        NaN   NaN  NaN          NaN
# 81046  2008-10-01T22:35:08.497        NaN   NaN  NaN          NaN
# 81047                      NaN        NaN   NaN  NaN          NaN
# 81048                      NaN        NaN   NaN  NaN          NaN
# 81049                      NaN        NaN   NaN  NaN          NaN
# 81050                      NaN        NaN   NaN  NaN          NaN
# 81051                      NaN        NaN   NaN  NaN          NaN
# 81052                      NaN        NaN   NaN  NaN          NaN
#
#        CommentCount  FavoriteCount
# 0                 0            NaN
# 1                10            NaN
# 2                 2            NaN
# 3                 1            NaN
# 4                 0            NaN
# 5                 0            NaN
# 6                 0            NaN
# 7                 4            NaN
# 8                 0            NaN
# 9                 0            NaN
# 10                4            NaN
# 11                0            NaN
# 12                0            NaN
# 13                1            NaN
# 14                0            NaN
# 15                0            NaN
# 16                0            NaN
# 17                2            NaN
# 18                6            NaN
# 19                0            NaN
# 20                0            NaN
# 21                0            NaN
# 22                2            NaN
# 23                1            NaN
# 24                0            NaN
# 25                1            NaN
# 26                3            NaN
# 27                0            NaN
# 28                0            NaN
# 29                1            NaN
# ...             ...            ...
# 81023             0            NaN
# 81024             0            NaN
# 81025             1            NaN
# 81026             0            NaN
# 81027             1            NaN
# 81028             0            NaN
# 81029             0            NaN
# 81030             3            NaN
# 81031             1            NaN
# 81032             1            NaN
# 81033             0            NaN
# 81034             3            NaN
# 81035             0            NaN
# 81036             0            NaN
# 81037             0            NaN
# 81038             3            NaN
# 81039             2            NaN
# 81040             1            NaN
# 81041             0            NaN
# 81042             0            NaN
# 81043             3            NaN
# 81044             7            NaN
# 81045             0            NaN
# 81046             0            NaN
# 81047             0            NaN
# 81048             1            NaN
# 81049             0            NaN
# 81050             0            NaN
# 81051             0            NaN
# 81052             2            NaN
#
# [81053 rows x 20 columns]

# %%
df_answers_time.head()
# Out:
#       Cr_time  ParentID
# 0  1217542677       4.0
# 1  1217548601      11.0
# 2  1217567564      17.0
# 3  1217581047       9.0
# 4  1217592439       9.0

# %%
parents_time = Parents_post.CreationDate.str[:-4]

# %%
unix_parents = [date_ts(i) for i in parents_time]

# %%
df_parents_time = pd.DataFrame({'Cr_time_parents':unix_parents, 'ParentID':Parents_post.Id})

# %%
df_parents_time.head()
# Out:
#    Cr_time_parents  ParentID
# 0       1217540572         4
# 1       1217542088         6
# 2       1217547659         9
# 3       1217548537        11
# 4       1217551358        13

# %% [markdown]
# ## Merge Table & Create Columns of mins and hours

# %%
df_compare = pd.merge(df_parents_time, df_answers_time, on='ParentID')

# %%
df_compare.head()
# Out:
#    Cr_time_parents ParentID     Cr_time
# 0       1217540572        4  1217542677
# 1       1217540572        4  1217598786
# 2       1217540572        4  1217600608
# 3       1217540572        4  1217967510
# 4       1217540572        4  1218390867

# %%
df_compare['Duration'] = df_compare.Cr_time - df_compare.Cr_time_parents

# %%
df_compare['Duration_mins'] = df_compare.Duration/60

# %%
df_compare['Duration_hours'] = df_compare.Duration_mins/60

# %%
df_compare.head()
# Out:
#    Cr_time_parents ParentID     Cr_time  Duration  Duration_mins  \
# 0       1217540572        4  1217542677      2105      35.083333
# 1       1217540572        4  1217598786     58214     970.233333
# 2       1217540572        4  1217600608     60036    1000.600000
# 3       1217540572        4  1217967510    426938    7115.633333
# 4       1217540572        4  1218390867    850295   14171.583333
#
#    Duration_hours
# 0        0.584722
# 1       16.170556
# 2       16.676667
# 3      118.593889
# 4      236.193056

# %%
df_compare.Duration_mins.describe()
# Out:
# count    80995.000000
# mean      2283.904162
# std       8624.629899
# min     -44770.133333
# 25%          7.183333
# 50%         23.300000
# 75%        185.325000
# max      87521.316667
# Name: Duration_mins, dtype: float64

# %%
df_compare.Duration_hours.describe()
# Out:
# count    80995.000000
# mean        38.065069
# std        143.743832
# min       -746.168889
# 25%          0.119722
# 50%          0.388333
# 75%          3.088750
# max       1458.688611
# Name: Duration_hours, dtype: float64

# %%
neg = 0
pos = 0
for i in df_compare.Duration_hours:
    if i >= 0:
        pos += 1
    else:
        neg += 1
print(pos, neg)

#15 negative duration, possibly an error from collecting data
#ie. negative duration means answer being posted before the parents questions being posted (not possible)
# Out:
# 80980 15

# %%
df_compare.head()
# Out:
#    Cr_time_parents ParentID     Cr_time  Duration  Duration_mins  \
# 0       1217540572        4  1217542677      2105      35.083333
# 1       1217540572        4  1217598786     58214     970.233333
# 2       1217540572        4  1217600608     60036    1000.600000
# 3       1217540572        4  1217967510    426938    7115.633333
# 4       1217540572        4  1218390867    850295   14171.583333
#
#    Duration_hours
# 0        0.584722
# 1       16.170556
# 2       16.676667
# 3      118.593889
# 4      236.193056

# %% [markdown]
# ## Calculate Frequency and Probability of mins and hours

# %%
Duration_mins_rounded = df_compare.Duration_mins.round()

# %%
fre_mins = pd.DataFrame(Duration_mins_rounded.value_counts(), index=None)
fre_mins['mins'] = fre_mins.index
fre_mins = fre_mins.rename(columns={'Duration_mins':'Frequency','mins':'mins'})
fre_mins.reset_index(inplace=True, drop=True)
#drop negative mins
fre_mins.drop(fre_mins[fre_mins.mins < 0].index, inplace=True)
fre_mins = fre_mins.sort_values('mins')

# %%
fre_mins.head()
# Out:
#     Frequency  mins
# 75        122   0.0
# 13       1178   1.0
# 3        3156   2.0
# 0        3704   3.0
# 1        3701   4.0

# %%
fre_mins['Probabiity'] = fre_mins.Frequency/sum(fre_mins.Frequency)

# %%
fre_mins.head()
# Out:
#     Frequency  mins  Probabiity
# 75        122   0.0    0.001507
# 13       1178   1.0    0.014547
# 3        3156   2.0    0.038973
# 0        3704   3.0    0.045740
# 1        3701   4.0    0.045703

# %%
fre_mins.Probabiity.describe()
# Out:
# count    9831.000000
# mean        0.000102
# std         0.001244
# min         0.000012
# 25%         0.000012
# 50%         0.000012
# 75%         0.000025
# max         0.045740
# Name: Probabiity, dtype: float64

# %% [markdown]
# ## Plot (Probability)

# %%
plt.plot(fre_mins.mins, fre_mins.Probabiity)
plt.xlim(0,200)
plt.grid()
plt.title('Probability of Answered in terms of Minutes')
# Out:
# Text(0.5,1,'Probability of Answered in terms of Minutes')

# %% [markdown]
# ## Cumulative Probability

# %%
fre_mins.head()
# Out:
#     Frequency  mins  Probabiity
# 75        122   0.0    0.001507
# 13       1178   1.0    0.014547
# 3        3156   2.0    0.038973
# 0        3704   3.0    0.045740
# 1        3701   4.0    0.045703

# %%
fre_mins['cum_pro'] = np.cumsum(list(fre_mins.Probabiity))

# %%
fre_mins.head()
# Out:
#     Frequency  mins  Probabiity   cum_pro
# 75        122   0.0    0.001507  0.001507
# 13       1178   1.0    0.014547  0.016053
# 3        3156   2.0    0.038973  0.055026
# 0        3704   3.0    0.045740  0.100766
# 1        3701   4.0    0.045703  0.146468

# %%
plt.plot(fre_mins.mins, fre_mins.cum_pro, color='red')
plt.xlim(0,200)
plt.grid()
plt.title('cumulative probability')
plt.xlabel('cumulative probability')
# Out:
# Text(0.5,0,'cumulative probability')

# %% [markdown]
# ## Summary of Probability Plots

# %%
plt.subplot(221)
plt.plot(fre_mins.mins, fre_mins.Probabiity)
plt.xlim(0,200)
plt.grid()
plt.title('probability')
plt.subplot(222)
plt.plot(fre_mins.mins, fre_mins.cum_pro, color='red')
plt.xlim(0,200)
plt.grid()
plt.title('cumulative probability')
plt.xlabel('cumulative probability')
# Out:
# Text(0.5,0,'cumulative probability')
